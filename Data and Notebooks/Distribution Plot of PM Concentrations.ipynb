# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
airqual = pd.read_csv('POC 1 data v2.csv')

# %%
airqual.head()
# Out:
#        Date  AQS_SITE_ID  POC  Daily Mean PM2.5 Concentration     UNITS  \
# 0  1/1/2017     60371103    1                            12.2  ug/m3 LC
# 1  1/2/2017     60371103    1                             7.4  ug/m3 LC
# 2  1/3/2017     60371103    1                            11.4  ug/m3 LC
# 3  1/4/2017     60371103    1                            13.9  ug/m3 LC
# 4  1/5/2017     60371103    1                             5.1  ug/m3 LC
#
#    DAILY_AQI_VALUE  DAILY_OBS_COUNT  PERCENT_COMPLETE  AQS_PARAMETER_CODE  \
# 0               51                1               100               88101
# 1               31                1               100               88101
# 2               48                1               100               88101
# 3               55                1               100               88101
# 4               21                1               100               88101
#
#          AQS_PARAMETER_DESC  CBSA_CODE                           CBSA_NAME  \
# ...

# %%
airqual.drop('AQS_SITE_ID', axis=1, inplace = True)
airqual.drop('POC', axis=1, inplace = True)

# %%
airqual.head()
# Out:
#        Date  Daily Mean PM2.5 Concentration     UNITS  DAILY_AQI_VALUE  \
# 0  1/1/2017                            12.2  ug/m3 LC               51
# 1  1/2/2017                             7.4  ug/m3 LC               31
# 2  1/3/2017                            11.4  ug/m3 LC               48
# 3  1/4/2017                            13.9  ug/m3 LC               55
# 4  1/5/2017                             5.1  ug/m3 LC               21
#
#    DAILY_OBS_COUNT  PERCENT_COMPLETE  AQS_PARAMETER_CODE  \
# 0                1               100               88101
# 1                1               100               88101
# 2                1               100               88101
# 3                1               100               88101
# 4                1               100               88101
#
#          AQS_PARAMETER_DESC  CBSA_CODE                           CBSA_NAME  \
# 0  PM2.5 - Local Conditions      31080  Los Angeles-Long Beach-Anaheim, CA
# ...

# %%
sns.distplot(airqual['Daily Mean PM2.5 Concentration'])
# Out:
# C:\Users\theda\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
