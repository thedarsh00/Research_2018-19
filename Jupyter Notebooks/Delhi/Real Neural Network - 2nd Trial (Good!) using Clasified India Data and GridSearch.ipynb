# %%
# %matplotlib inline               
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('india data PM10 classified.csv')

# %%
df.head()
# Out:
#    PM 10  Max Temp  Avg Dew Point  Max Wind Speed  Avg Humidity  Max Humidity  \
# 0      0        96             70               9          58.5            83
# 1      0       108             61              15          31.0            53
# 2      0       109             69               7          34.0            49
# 3      1        58             50               6          81.5            97
# 4      1        71             61              14          84.0           100
#
#    Max Pressure  Min Pressure  Precipitation
# 0         29.76         29.65           0.08
# 1         29.62         29.47           0.00
# 2         29.60         29.45           0.00
# 3         30.11         29.96           0.00
# 4         29.97         29.83           0.28

# %%
df.describe()
# Out:
#             PM 10    Max Temp  Avg Dew Point  Max Wind Speed  Avg Humidity  \
# count  248.000000  248.000000     248.000000      248.000000    248.000000
# mean     1.459677   90.137097      65.879032        9.403226     59.286290
# std      0.653848   11.625976       9.574420        5.069428     13.767763
# min      0.000000   58.000000      45.000000        0.000000     20.000000
# 25%      1.000000   82.000000      59.750000        6.000000     51.500000
# 50%      1.000000   93.500000      66.000000        9.000000     60.750000
# 75%      2.000000   97.250000      75.000000       12.250000     69.000000
# max      3.000000  113.000000      80.000000       34.000000     91.500000
#
#        Max Humidity  Max Pressure  Min Pressure  Precipitation
# count    248.000000    248.000000    248.000000     248.000000
# mean      81.306452     29.818710     29.693548       0.034355
# std       14.891335      0.216516      0.217841       0.165131
# min       29.000000     29.420000     29.310000       0.000000
# 25%       74.000000     29.620000     29.487500       0.000000
# 50%       86.000000     29.825000     29.685000       0.000000
# 75%       93.000000     30.010000     29.890000       0.000000
# max      100.000000     30.220000     30.120000       1.610000

# %%
df.shape
# Out:
# (248, 9)

# %%
X = df.drop('PM 10',axis=1)
y = np.asarray(df['PM 10'], dtype="|S6")

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train.shape
# Out:
# (198, 8)

# %%
X_test.shape
# Out:
# (50, 8)

# %%
y_train.shape
# Out:
# (198,)

# %%
y_test.shape
# Out:
# (50,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(max_iter=2000)

parameter_space = {
    'hidden_layer_sizes': [(2, 2, 2), (4, 4, 4), (6, 6, 6), (8, 8, 8), (10, 10, 10), (12, 12, 12)],
    'activation': ['identity', 'logistic', 'tanh', 'relu'],
    'solver': ['lbfgs', 'sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
}

# %%
from sklearn.model_selection import GridSearchCV

clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=3)
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise',
#        estimator=MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=2000, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'hidden_layer_sizes': [(2, 2, 2), (4, 4, 4), (6, 6, 6), (8, 8, 8), (10, 10, 10), (12, 12, 12)], 'activation': ['identity', 'logistic', 'tanh', 'relu'], 'solver': ['lbfgs', 'sgd', 'adam'], 'alpha': [0.0001, 0.05], 'learning_rate': ['constant', 'adaptive']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
# Best parameter set
print('Best parameters found:\n', clf.best_params_)

# All results
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Best parameters found:
#  {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (12, 12, 12), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.566 (+/-0.024) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.551 (+/-0.087) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.561 (+/-0.058) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.566 (+/-0.024) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.510 (+/-0.019) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.561 (+/-0.039) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.545 (+/-0.076) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.556 (+/-0.043) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.530 (+/-0.021) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.571 (+/-0.059) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.520 (+/-0.055) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.551 (+/-0.046) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.535 (+/-0.071) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.540 (+/-0.044) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 8, 8), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.581 (+/-0.024) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 8, 8), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.586 (+/-0.108) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 8, 8), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 8, 8), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.551 (+/-0.055) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 8, 8), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.581 (+/-0.073) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 8, 8), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.540 (+/-0.058) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.566 (+/-0.057) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.556 (+/-0.116) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.586 (+/-0.045) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (12, 12, 12), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.525 (+/-0.050) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (12, 12, 12), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.571 (+/-0.058) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (12, 12, 12), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (12, 12, 12), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.561 (+/-0.093) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (12, 12, 12), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.591 (+/-0.058) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (12, 12, 12), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.566 (+/-0.024) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.540 (+/-0.059) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.545 (+/-0.053) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.566 (+/-0.024) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.561 (+/-0.052) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.571 (+/-0.058) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.551 (+/-0.115) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.535 (+/-0.081) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.571 (+/-0.045) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.530 (+/-0.045) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.581 (+/-0.082) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.561 (+/-0.129) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.556 (+/-0.060) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.556 (+/-0.062) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (8, 8, 8), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.556 (+/-0.044) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (8, 8, 8), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.556 (+/-0.101) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (8, 8, 8), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (8, 8, 8), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.551 (+/-0.060) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (8, 8, 8), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.586 (+/-0.036) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (8, 8, 8), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.551 (+/-0.048) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.576 (+/-0.070) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.571 (+/-0.067) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.556 (+/-0.043) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (12, 12, 12), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.551 (+/-0.069) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (12, 12, 12), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.576 (+/-0.070) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (12, 12, 12), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.571 (+/-0.020) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (12, 12, 12), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.556 (+/-0.101) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (12, 12, 12), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.596 (+/-0.072) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (12, 12, 12), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.586 (+/-0.101) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.561 (+/-0.014) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.561 (+/-0.014) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.571 (+/-0.127) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.561 (+/-0.014) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.561 (+/-0.014) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (2, 2, 2), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.667 (+/-0.086) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.561 (+/-0.014) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.561 (+/-0.014) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.601 (+/-0.091) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.561 (+/-0.014) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.561 (+/-0.014) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (4, 4, 4), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.692 (+/-0.193) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.561 (+/-0.014) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.561 (+/-0.014) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.616 (+/-0.066) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'lbfgs'}
# 0.561 (+/-0.014) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.561 (+/-0.014) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (6, 6, 6), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.697 (+/-0.220) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 8, 8), 'learning_rate': 'constant', 'solver': 'lbfgs'}
# 0.561 (+/-0.014) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (8, 8, 8), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0